# %%
from models.MGNN_net import MGNN

mgnn = MGNN(
    n_vertices=50,
    n_features=1,
    n_classes=2,
    n_hidden=16,
    n_layers=3,
    dropout=0.5,
    activation='relu',
    batch_norm=True,
    residual=True,
    sparse=False,
    device='cuda'
)

print(mgnn)
# Out:
# MGNN(
#   (edge_to_node): Linear(in_features=2, out_features=64, bias=True)
#   (layer1_msg): Linear(in_features=64, out_features=64, bias=False)
#   (layer1_self): Linear(in_features=64, out_features=64, bias=True)
#   (layer2_msg): Linear(in_features=64, out_features=64, bias=False)
#   (layer2_self): Linear(in_features=64, out_features=64, bias=True)
# )
